# %%
import pandas as pd
import numpy as np
import openweathermapy.core as owm
from citipy import citipy as cp
from config import api_key
from datetime import datetime
import matplotlib.pyplot as plt

# %%
#Function to return City name
def get_city(vlat,vlon):
    geo = cp.nearest_city(vlat,vlon)
    return geo.city_name.title()

# %%
city_count=1000 # How many cities need to generate
city=[]

# Creating loop to add unique cities in the list
while (len(city) <city_count):
    city_name = get_city(np.random.uniform(low=-66, high=66),np.random.uniform(low=-180, high=180))
    if(city_name in city):
        print(f"{city_name} already exists in the list. Generating new ")
        city_name = get_city(np.random.randint(-40,40),np.random.randint(-120,120))
    else:
        city.append(city_name)

print(len(city))
cities_df=pd.DataFrame({"City":city})

cities_df["Latitude"]=""
cities_df["Longitude"]=""
cities_df["Country Code"]=""
cities_df["Max Temp"]=""
cities_df["Humidity"]=""
cities_df["Cloudiness"]=""
cities_df["Wind Speed (mph)"]=""
cities_df["Date"]=""
cities_df["Time"]=""
cities_df.head()
# Out:
# Rikitea already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Lompoc already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Grand Gaube already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Ancud already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Kavieng already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Marcona already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Poum already exists in the list. Generating new
# East London already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Belyy Yar already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Geraldton already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Kavieng already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Chuy already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Airai already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Ancud already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Bathsheba already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Broken Hill already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# East London already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Constitucion already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Avera already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Saint George already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Airai already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Saint George already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Vila Franca Do Campo already exists in the list. Generating new
# Lebu already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Norman Wells already exists in the list. Generating new
# Souillac already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Guerrero Negro already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Cabo San Lucas already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Salalah already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Belyy Yar already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Saint George already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Kloulklubed already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Sao Joao Da Barra already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Hambantota already exists in the list. Generating new
# Port Elizabeth already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Padang already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Touros already exists in the list. Generating new
# Rocha already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Sentyabrskiy already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Esperance already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Thompson already exists in the list. Generating new
# Aswan already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Tasiilaq already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Attawapiskat already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Bambous Virieux already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# San Juan already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Saint George already exists in the list. Generating new
# Ballina already exists in the list. Generating new
# Port Elizabeth already exists in the list. Generating new
# Tasiilaq already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Hamilton already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Mount Gambier already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Namibe already exists in the list. Generating new
# Padang already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Victoria already exists in the list. Generating new
# Yumen already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Pisco already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Bambous Virieux already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Victoria already exists in the list. Generating new
# New Norfolk already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Samusu already exists in the list. Generating new
# East London already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Lolua already exists in the list. Generating new
# Labuhan already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Kavieng already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# East London already exists in the list. Generating new
# Bambous Virieux already exists in the list. Generating new
# Isangel already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Bredasdorp already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Acapulco already exists in the list. Generating new
# Praia Da Vitoria already exists in the list. Generating new
# Inhambane already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Thompson already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Souillac already exists in the list. Generating new
# Touros already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Sentyabrskiy already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Kavaratti already exists in the list. Generating new
# Guerrero Negro already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Flin Flon already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Moose Factory already exists in the list. Generating new
# Vao already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Yumen already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Constitucion already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Lata already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Codrington already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Ancud already exists in the list. Generating new
# Tasiilaq already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Mount Gambier already exists in the list. Generating new
# Praia Da Vitoria already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Airai already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Te Anau already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Najran already exists in the list. Generating new
# Kahului already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Adrar already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Kavieng already exists in the list. Generating new
# Vaitupu already exists in the list. Generating new
# Cidreira already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Bengkulu already exists in the list. Generating new
# Airai already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Lolua already exists in the list. Generating new
# La Ronge already exists in the list. Generating new
# Broken Hill already exists in the list. Generating new
# Codrington already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Vila Velha already exists in the list. Generating new
# Port Blair already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Brae already exists in the list. Generating new
# Umzimvubu already exists in the list. Generating new
# Port Blair already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Sao Joao Da Barra already exists in the list. Generating new
# Bengkulu already exists in the list. Generating new
# Lompoc already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Yulara already exists in the list. Generating new
# Airai already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Paradwip already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Attawapiskat already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Nantucket already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Lebu already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Vila Franca Do Campo already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Terney already exists in the list. Generating new
# Touros already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Meulaboh already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Ancud already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Bredasdorp already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Chuy already exists in the list. Generating new
# Vila Velha already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Luderitz already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Vaitupu already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Esperance already exists in the list. Generating new
# Hambantota already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Port Elizabeth already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Bambous Virieux already exists in the list. Generating new
# Broome already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Victoria already exists in the list. Generating new
# Alofi already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Viedma already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Guerrero Negro already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Te Anau already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Constitucion already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Broome already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Nemuro already exists in the list. Generating new
# Saleaula already exists in the list. Generating new
# Jalu already exists in the list. Generating new
# Airai already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Ancud already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Ust-Kamchatsk already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Mareeba already exists in the list. Generating new
# Thompson already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Korla already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Lompoc already exists in the list. Generating new
# Louisbourg already exists in the list. Generating new
# Eyl already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Tasiilaq already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Lorengau already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Saint George already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Cabo San Lucas already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Cabo San Lucas already exists in the list. Generating new
# Sentyabrskiy already exists in the list. Generating new
# Lagoa already exists in the list. Generating new
# Geraldton already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Isangel already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Albany already exists in the list. Generating new
# San Quintin already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Bathsheba already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Alofi already exists in the list. Generating new
# Saint-Augustin already exists in the list. Generating new
# Saleaula already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Vaitupu already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Kruisfontein already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Cidreira already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Dingle already exists in the list. Generating new
# Kahului already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Kavaratti already exists in the list. Generating new
# Saleaula already exists in the list. Generating new
# Portland already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Broken Hill already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Lompoc already exists in the list. Generating new
# Esperance already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Isangel already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Umzimvubu already exists in the list. Generating new
# Sentyabrskiy already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Bambous Virieux already exists in the list. Generating new
# Yulara already exists in the list. Generating new
# Broome already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Bathsheba already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Esperance already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Lompoc already exists in the list. Generating new
# Hambantota already exists in the list. Generating new
# Mount Isa already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Avera already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# San Cristobal already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Thompson already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Poum already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Cuiluan already exists in the list. Generating new
# Lorengau already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# New Norfolk already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Korla already exists in the list. Generating new
# Grand Gaube already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Naze already exists in the list. Generating new
# Tahta already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Attawapiskat already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Bredasdorp already exists in the list. Generating new
# Yerbogachen already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# San Cristobal already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Tabiauea already exists in the list. Generating new
# Chuy already exists in the list. Generating new
# Guerrero Negro already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Rurrenabaque already exists in the list. Generating new
# Ucluelet already exists in the list. Generating new
# Attawapiskat already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Santa Maria already exists in the list. Generating new
# Carutapera already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Sentyabrskiy already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Porto Novo already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Weligama already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Palmer already exists in the list. Generating new
# Port Lincoln already exists in the list. Generating new
# Cockburn Town already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Okhotsk already exists in the list. Generating new
# Krasnoselkup already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Faanui already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Yerbogachen already exists in the list. Generating new
# Codrington already exists in the list. Generating new
# Katsuura already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# La Ronge already exists in the list. Generating new
# Saleaula already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Cabo San Lucas already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Adrar already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Lebu already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Ponta Do Sol already exists in the list. Generating new
# Padang already exists in the list. Generating new
# Broome already exists in the list. Generating new
# Bubaque already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Naze already exists in the list. Generating new
# Nemuro already exists in the list. Generating new
# East London already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Fortuna already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Tautira already exists in the list. Generating new
# Alofi already exists in the list. Generating new
# Aborlan already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Beringovskiy already exists in the list. Generating new
# Brae already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Mount Gambier already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Vila Franca Do Campo already exists in the list. Generating new
# Namibe already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Buraydah already exists in the list. Generating new
# Sao Filipe already exists in the list. Generating new
# San Quintin already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Luderitz already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Ahipara already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Verkhnevilyuysk already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Coquimbo already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Northam already exists in the list. Generating new
# Saint-Pierre already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Portland already exists in the list. Generating new
# Ponta Do Sol already exists in the list. Generating new
# Isangel already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Vila Franca Do Campo already exists in the list. Generating new
# Constitucion already exists in the list. Generating new
# Saleaula already exists in the list. Generating new
# Ponta Do Sol already exists in the list. Generating new
# Altay already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Bengkulu already exists in the list. Generating new
# Victoria already exists in the list. Generating new
# Albany already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Codrington already exists in the list. Generating new
# Torbay already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Bengkulu already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Mount Gambier already exists in the list. Generating new
# Poum already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Roma already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Lolua already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Faanui already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Yerbogachen already exists in the list. Generating new
# Puerto Carreno already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Thompson already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Torbay already exists in the list. Generating new
# Saint-Pierre already exists in the list. Generating new
# Port Lincoln already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Quatre Cocos already exists in the list. Generating new
# Attawapiskat already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Constitucion already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Alofi already exists in the list. Generating new
# Ponta Do Sol already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Codrington already exists in the list. Generating new
# Meulaboh already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Vao already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Lavrentiya already exists in the list. Generating new
# Faanui already exists in the list. Generating new
# Kavaratti already exists in the list. Generating new
# Nantucket already exists in the list. Generating new
# Marcona already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Touros already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Avera already exists in the list. Generating new
# Guerrero Negro already exists in the list. Generating new
# Cidreira already exists in the list. Generating new
# Torbay already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Broome already exists in the list. Generating new
# Esperance already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Isangel already exists in the list. Generating new
# Grand Gaube already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Airai already exists in the list. Generating new
# Maniitsoq already exists in the list. Generating new
# Meulaboh already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Thompson already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Grindavik already exists in the list. Generating new
# Kasongo-Lunda already exists in the list. Generating new
# Torbay already exists in the list. Generating new
# Vaitupu already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Umm Lajj already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Verkhnyaya Inta already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Hasaki already exists in the list. Generating new
# Katsuura already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Ahipara already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Nantucket already exists in the list. Generating new
# Portland already exists in the list. Generating new
# Caravelas already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Kruisfontein already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Half Moon Bay already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Hays already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Bathsheba already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Christchurch already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Port-Gentil already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# East London already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Lorengau already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Lompoc already exists in the list. Generating new
# Thompson already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Hamilton already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Port Elizabeth already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Isangel already exists in the list. Generating new
# Cidreira already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Sao Joao Da Barra already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Kieta already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Port Blair already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Cairns already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Lompoc already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Takoradi already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Los Llanos De Aridane already exists in the list. Generating new
# Carutapera already exists in the list. Generating new
# Sitka already exists in the list. Generating new
# ...
# Puerto Ayora already exists in the list. Generating new
# Tsihombe already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Cotonou already exists in the list. Generating new
# New Norfolk already exists in the list. Generating new
# Iqaluit already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Chuy already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Sentyabrskiy already exists in the list. Generating new
# Ancud already exists in the list. Generating new
# Constitucion already exists in the list. Generating new
# Marsaxlokk already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Umzimvubu already exists in the list. Generating new
# Caravelas already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Tasiilaq already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Vaitupu already exists in the list. Generating new
# Ponta Do Sol already exists in the list. Generating new
# Bengkulu already exists in the list. Generating new
# Pangnirtung already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Hamilton already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Coxim already exists in the list. Generating new
# Margate already exists in the list. Generating new
# Tsihombe already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Saldanha already exists in the list. Generating new
# Bandarbeyla already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Rocha already exists in the list. Generating new
# Tuatapere already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Kahului already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Gamba already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Camacha already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Vaini already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Tessalit already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Aswan already exists in the list. Generating new
# Bubaque already exists in the list. Generating new
# Rio Gallegos already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Marcona already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Iqaluit already exists in the list. Generating new
# Hualmay already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Victoria already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Victoria already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Port Alfred already exists in the list. Generating new
# Goderich already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Umm Lajj already exists in the list. Generating new
# Anadyr already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Dingle already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Mar Del Plata already exists in the list. Generating new
# Sao Filipe already exists in the list. Generating new
# Bengkulu already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Atar already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Touros already exists in the list. Generating new
# Lolua already exists in the list. Generating new
# Alotau already exists in the list. Generating new
# Cidreira already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Salalah already exists in the list. Generating new
# Nabire already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Samusu already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# North Branch already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Petropavlovsk-Kamchatskiy already exists in the list. Generating new
# Norman Wells already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Mount Isa already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Faanui already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Taolanaro already exists in the list. Generating new
# Grand River South East already exists in the list. Generating new
# Goderich already exists in the list. Generating new
# Camacha already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Carnarvon already exists in the list. Generating new
# Port Elizabeth already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Northam already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hermanus already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Paamiut already exists in the list. Generating new
# Busselton already exists in the list. Generating new
# Cabo San Lucas already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Sola already exists in the list. Generating new
# Gogrial already exists in the list. Generating new
# Ponta Do Sol already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Hami already exists in the list. Generating new
# Nuuk already exists in the list. Generating new
# Esperance already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Guerrero Negro already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Kutum already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Arraial Do Cabo already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Iqaluit already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# East London already exists in the list. Generating new
# Emmett already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Lorengau already exists in the list. Generating new
# Kavieng already exists in the list. Generating new
# San Quintin already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Sitka already exists in the list. Generating new
# Nanortalik already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Saint-Joseph already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Sao Filipe already exists in the list. Generating new
# Faya already exists in the list. Generating new
# Hualmay already exists in the list. Generating new
# Bluff already exists in the list. Generating new
# Kapaa already exists in the list. Generating new
# Samusu already exists in the list. Generating new
# Saleaula already exists in the list. Generating new
# Vaitupu already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Cockburn Town already exists in the list. Generating new
# Inhambane already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Keningau already exists in the list. Generating new
# Mount Gambier already exists in the list. Generating new
# Port Hardy already exists in the list. Generating new
# Sao Joao Da Barra already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Cape Town already exists in the list. Generating new
# Broken Hill already exists in the list. Generating new
# Tuatapere already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hobart already exists in the list. Generating new
# Pisco already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Arlit already exists in the list. Generating new
# Mount Gambier already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Tsihombe already exists in the list. Generating new
# Port Elizabeth already exists in the list. Generating new
# Tsihombe already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Alofi already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Punta Arenas already exists in the list. Generating new
# Maniitsoq already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Falealupo already exists in the list. Generating new
# Saint George already exists in the list. Generating new
# Faanui already exists in the list. Generating new
# Saldanha already exists in the list. Generating new
# Natal already exists in the list. Generating new
# Kaitangata already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Georgetown already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Sola already exists in the list. Generating new
# Mayumba already exists in the list. Generating new
# Gurgan already exists in the list. Generating new
# Nikolskoye already exists in the list. Generating new
# Lebu already exists in the list. Generating new
# Esperance already exists in the list. Generating new
# Castro already exists in the list. Generating new
# Severo-Kurilsk already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Acapulco already exists in the list. Generating new
# Avarua already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Sao Filipe already exists in the list. Generating new
# Kavaratti already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Hilo already exists in the list. Generating new
# Nuuk already exists in the list. Generating new
# Marcona already exists in the list. Generating new
# Isangel already exists in the list. Generating new
# Nalut already exists in the list. Generating new
# Hithadhoo already exists in the list. Generating new
# Geraldton already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Iqaluit already exists in the list. Generating new
# Ribeira Grande already exists in the list. Generating new
# Mega already exists in the list. Generating new
# Mahebourg already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Vilyuysk already exists in the list. Generating new
# Puerto Ayora already exists in the list. Generating new
# Yellowknife already exists in the list. Generating new
# Saint George already exists in the list. Generating new
# Kodiak already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Vila Franca Do Campo already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# Mataura already exists in the list. Generating new
# Matara already exists in the list. Generating new
# Pisco already exists in the list. Generating new
# Gamba already exists in the list. Generating new
# Bredasdorp already exists in the list. Generating new
# Coahuayana already exists in the list. Generating new
# Palmer already exists in the list. Generating new
# San Patricio already exists in the list. Generating new
# Jamestown already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Bethel already exists in the list. Generating new
# Jalu already exists in the list. Generating new
# Adrar already exists in the list. Generating new
# Bambous Virieux already exists in the list. Generating new
# Te Anau already exists in the list. Generating new
# Butaritari already exists in the list. Generating new
# Saint-Pierre already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Pangkalanbuun already exists in the list. Generating new
# Hualmay already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Saint-Philippe already exists in the list. Generating new
# Hami already exists in the list. Generating new
# Grindavik already exists in the list. Generating new
# Avera already exists in the list. Generating new
# Albany already exists in the list. Generating new
# Roma already exists in the list. Generating new
# Torbay already exists in the list. Generating new
# Shingu already exists in the list. Generating new
# Tasiilaq already exists in the list. Generating new
# Atuona already exists in the list. Generating new
# Kushima already exists in the list. Generating new
# Rikitea already exists in the list. Generating new
# Ushuaia already exists in the list. Generating new
# Provideniya already exists in the list. Generating new
# 1000
#            City Latitude Longitude Country Code Max Temp Humidity Cloudiness  \
# 0     Caravelas
# 1       Isangel
# 2  Puerto Ayora
# 3        Namibe
# 4          Brae
#
#   Wind Speed (mph) Date Time
# 0
# 1
# 2
# 3
# 4

# %%
settings = {"units": "imperial", "appid": api_key}
for index,row in cities_df.iterrows():
    try:
        weather_city = owm.get_current(row["City"], **settings)
        #Adding if condition to print initial 5 records
        if(index <=5):
            print(weather_city)
        cities_df.loc[index, "Latitude"]=weather_city["coord"]["lat"]  
        cities_df.loc[index, "Longitude"]=weather_city["coord"]["lon"] 
        cities_df.loc[index, "Wind Speed (mph)"]=weather_city['wind']['speed'] 
        cities_df.loc[index, "Max Temp"]= weather_city["main"]["temp_max"]
        cities_df.loc[index, "Humidity"]=weather_city["main"]["humidity"] 
        cities_df.loc[index, "Cloudiness"]=weather_city["clouds"]["all"] 
        cities_df.loc[index,"Date"]=datetime.fromtimestamp(weather_city["dt"]).strftime("%m/%d/%Y")
        cities_df.loc[index,"Time"]=datetime.fromtimestamp(weather_city["dt"]).strftime("%I:%M:%S")
        cities_df.loc[index,"Country Code"]=weather_city["sys"]["country"] 

    except:
        #Removing cities for which weather is not available in weathermapi
        print(f"Weather not available for city {cities_df.loc[index,'City']}. Deleting it from DataFrame")
        cities_df.drop(index,inplace=True)
        continue

cities_df.head()
# Out:
# {'coord': {'lon': -39.27, 'lat': -17.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.85, 'pressure': 1027.1, 'humidity': 100, 'temp_min': 78.85, 'temp_max': 78.85, 'sea_level': 1027.09, 'grnd_level': 1027.1}, 'wind': {'speed': 11.54, 'deg': 116.502}, 'clouds': {'all': 0}, 'dt': 1522444942, 'sys': {'message': 0.0062, 'country': 'BR', 'sunrise': 1522399386, 'sunset': 1522442346}, 'id': 3466980, 'name': 'Caravelas', 'cod': 200}
# {'coord': {'lon': 169.27, 'lat': -19.55}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.57, 'pressure': 1020.13, 'humidity': 100, 'temp_min': 79.57, 'temp_max': 79.57, 'sea_level': 1022.15, 'grnd_level': 1020.13}, 'wind': {'speed': 17.58, 'deg': 133.502}, 'clouds': {'all': 56}, 'dt': 1522444943, 'sys': {'message': 0.0034, 'country': 'VU', 'sunrise': 1522349361, 'sunset': 1522392291}, 'id': 2136825, 'name': 'Isangel', 'cod': 200}
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 82.4, 'pressure': 1011, 'humidity': 69, 'temp_min': 82.4, 'temp_max': 82.4}, 'visibility': 10000, 'wind': {'speed': 13.87, 'deg': 80}, 'clouds': {'all': 20}, 'dt': 1522440000, 'sys': {'type': 1, 'id': 4355, 'message': 0.1633, 'country': 'EC', 'sunrise': 1522411347, 'sunset': 1522454912}, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# {'coord': {'lon': 12.15, 'lat': -15.19}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.18, 'pressure': 1019.89, 'humidity': 100, 'temp_min': 78.18, 'temp_max': 78.18, 'sea_level': 1023.61, 'grnd_level': 1019.89}, 'wind': {'speed': 11.54, 'deg': 203.002}, 'clouds': {'all': 0}, 'dt': 1522444944, 'sys': {'message': 0.0034, 'country': 'AO', 'sunrise': 1522386999, 'sunset': 1522430059}, 'id': 3347019, 'name': 'Namibe', 'cod': 200}
# {'coord': {'lon': -1.35, 'lat': 60.4}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 33.28, 'pressure': 1012, 'humidity': 74, 'temp_min': 30.2, 'temp_max': 35.6}, 'visibility': 10000, 'wind': {'speed': 3.36}, 'clouds': {'all': 76}, 'dt': 1522443000, 'sys': {'type': 1, 'id': 5126, 'message': 0.1637, 'country': 'GB', 'sunrise': 1522388031, 'sunset': 1522435610}, 'id': 2654970, 'name': 'Brae', 'cod': 200}
# Weather not available for city Tabiauea . Removing it from list
# Weather not available for city Jiddah . Removing it from list
# Weather not available for city Ngukurr . Removing it from list
# Weather not available for city Taolanaro . Removing it from list
# Weather not available for city Vaitupu . Removing it from list
# Weather not available for city Marcona . Removing it from list
# Weather not available for city Bengkulu . Removing it from list
# Weather not available for city Paradwip . Removing it from list
# Weather not available for city Saleaula . Removing it from list
# Weather not available for city Grande-Riviere . Removing it from list
# Weather not available for city Cumaribo . Removing it from list
# Weather not available for city Louisbourg . Removing it from list
# Weather not available for city Odweyne . Removing it from list
# Weather not available for city Guelengdeng . Removing it from list
# Weather not available for city Krasnoselkup . Removing it from list
# Weather not available for city Umm Ruwabah . Removing it from list
# Weather not available for city Guajara-Mirim . Removing it from list
# Weather not available for city Guaratinga . Removing it from list
# Weather not available for city Attawapiskat . Removing it from list
# Weather not available for city Asayita . Removing it from list
# Weather not available for city Grand River South East . Removing it from list
# Weather not available for city Kashi . Removing it from list
# Weather not available for city Sentyabrskiy . Removing it from list
# Weather not available for city Mankovo-Kalitvenskoye . Removing it from list
# Weather not available for city Samusu . Removing it from list
# Weather not available for city Acarau . Removing it from list
# Weather not available for city Lolua . Removing it from list
# Weather not available for city Gurskoye . Removing it from list
# Weather not available for city Halalo . Removing it from list
# Weather not available for city Cagayan De Tawi-Tawi . Removing it from list
# Weather not available for city Tahta . Removing it from list
# Weather not available for city Ust-Kamchatsk . Removing it from list
# Weather not available for city Sataua . Removing it from list
# Weather not available for city Umzimvubu . Removing it from list
# Weather not available for city Masjed-E Soleyman . Removing it from list
# Weather not available for city Gogrial . Removing it from list
# Weather not available for city Nguiu . Removing it from list
# Weather not available for city Korla . Removing it from list
# Weather not available for city Kapoeta . Removing it from list
# Weather not available for city Barawe . Removing it from list
# Weather not available for city Utiroa . Removing it from list
# Weather not available for city Doctor Pedro P. Pena . Removing it from list
# Weather not available for city Kalimnos . Removing it from list
# Weather not available for city Gurgan . Removing it from list
# Weather not available for city Palabuhanratu . Removing it from list
# Weather not available for city Ardahan . Removing it from list
# Weather not available for city Tawzar . Removing it from list
# Weather not available for city Malwan . Removing it from list
# Weather not available for city Phan Rang . Removing it from list
# Weather not available for city Malakal . Removing it from list
# Weather not available for city Toliary . Removing it from list
# Weather not available for city Agva . Removing it from list
# Weather not available for city Raga . Removing it from list
# Weather not available for city Koungou . Removing it from list
# Weather not available for city Ambodifototra . Removing it from list
# Weather not available for city Aflu . Removing it from list
# Weather not available for city Falealupo . Removing it from list
# Weather not available for city Wad Madani . Removing it from list
# Weather not available for city Dzhusaly . Removing it from list
# Weather not available for city Dumitresti . Removing it from list
# Weather not available for city Wulanhaote . Removing it from list
# Weather not available for city Hihifo . Removing it from list
# Weather not available for city Tsihombe . Removing it from list
# Weather not available for city Jurado . Removing it from list
# Weather not available for city Vestbygda . Removing it from list
# Weather not available for city Cazaje . Removing it from list
# Weather not available for city Cozumel . Removing it from list
# Weather not available for city Mananara . Removing it from list
# Weather not available for city Okandja . Removing it from list
# Weather not available for city Warqla . Removing it from list
# Weather not available for city Shirgaon . Removing it from list
# Weather not available for city Kazalinsk . Removing it from list
# Weather not available for city Balykshi . Removing it from list

# %%
cities_df['Latitude']=pd.to_numeric(cities_df['Latitude'])
cities_df['Max Temp']=pd.to_numeric(cities_df['Max Temp'])
cities_df['Humidity']=pd.to_numeric(cities_df['Humidity'])
cities_df['Cloudiness']=pd.to_numeric(cities_df['Cloudiness'])
cities_df['Wind Speed (mph)']=pd.to_numeric(cities_df['Wind Speed (mph)'])

cities_df.head()

# %%
#plt.scatter(cities_df["Latitude"], "Temperature(F)"], marker="o", facecolors="red", edgecolors="black", alpha=0.75)
#cities_df.plot(kind="scatter",x="Latitude",y="temp_max",marker="o")

with plt.style.context('seaborn-dark'):
    plt.title(f"City Latitude vs Max Temperature ({cities_df['Date'][0]} {cities_df['Time'][0]})")
    plt.xlim(-90,90)
    plt.ylim(min(cities_df['Max Temp'])-10,max(cities_df['Max Temp'])+10)
    plt.xlabel("Latitude")
    plt.ylabel("Max Temperature (F)")
    plt.grid(color='white', linestyle='-', linewidth=1)
    plt.scatter(cities_df["Latitude"], cities_df["Max Temp"],edgecolors="black", color="blue", alpha=.8)

# %%
with plt.style.context('seaborn-dark'):
    plt.title(f"Latitude vs. Humidity ({cities_df['Date'][0]} {cities_df['Time'][0]})")
    plt.xlim(-90,90)
    plt.ylim(min(cities_df['Humidity'])-20,max(cities_df['Humidity'])+10)
    plt.xlabel("Latitude")
    plt.ylabel("Humidity (%)")
    plt.grid(color='white', linestyle='-', linewidth=1)
    plt.scatter(cities_df["Latitude"], cities_df["Humidity"],edgecolors="black", color="blue", alpha=.8)

# %%
with plt.style.context('seaborn-dark'):
    plt.title(f"Latitude vs. Cloudiness ({cities_df['Date'][0]} {cities_df['Time'][0]})")
    plt.xlim(-90,90)
    plt.ylim(min(cities_df['Cloudiness'])-20,max(cities_df['Cloudiness'])+20)
    plt.xlabel("Latitude")
    plt.ylabel("Cloudiness (%)")
    plt.grid(color='white', linestyle='-', linewidth=1)
    plt.scatter(cities_df["Latitude"], cities_df["Cloudiness"],edgecolors="black", color="blue", alpha=.8)

# %%
with plt.style.context('seaborn-dark'):
    plt.title(f"Latitude vs. Wind Speed ({cities_df['Date'][0]} {cities_df['Time'][0]})")
    plt.xlim(-90,90)
    plt.ylim(min(cities_df['Wind Speed (mph)'])-10,max(cities_df['Wind Speed (mph)'])+20)
    plt.xlabel("Latitude")
    plt.ylabel("Wind Speed (mph)")
    plt.grid(color='white', linestyle='-', linewidth=1)
    plt.scatter(cities_df["Latitude"], cities_df["Wind Speed (mph)"],edgecolors="black", color="blue", alpha=.8)
